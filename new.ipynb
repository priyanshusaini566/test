# %% [markdown]
# # problem-7

# %%
n=int(input("Enter the number : "))
fact=1

for i in range(n,0,-1):
    fact=fact*i

print(f"the factorial of {n} will be : ",fact)
# Out:
# the factorial of 8 will be :  40320

# %% [markdown]
# # problem-8

# %%
d={}
n=int(input("enter the number : "))
for i in range(1,n+1):
    d[i]=i*i

print(d)
# Out:
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64}

# %% [markdown]
# # problem-9

# %%
values=input()
l=values.split(",")
t=tuple(l)
print(l)
print(t)
# Out:
# ['a', 's', 'd', 'f']
# ('a', 's', 'd', 'f')

# %% [markdown]
# # problem-10

# %%
class jakhm():
    def getstring(self,s):
        self._s=s

    def printstring(self):
        print("the string is : ",(self._s.upper()))


s=input("enter the string : ")
j1=jakhm()
j1.getstring(s)
j1.printstring()
# Out:
# the string is :  PS
